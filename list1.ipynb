# %% [markdown]
# <a href="https://colab.research.google.com/github/upendrasapati/sapati/blob/main/list1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
string="ron was born on 12-09-1992 and was admitted to school on 15-12-1999"
print(re.sub(pattern,monday,string))






















































































































































































































































































































m0=re.findall(pattern,string)
#print(m0)
print(re.sub(pattern,monday,string))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f7d73c9a8c3> in <module>()
#       1 import re
#       2 string="ron was born on 12-09-1992 and was admitted to school on 15-12-1999"
# ----> 3 print(re.sub(pattern,monday,string))
#       4
#       5
#
# NameError: name 'pattern' is not defined

# %%
list=[12,13,14,15]

list.remove(14)
print("the list:",list)
# Out:
# the list: [12, 13, 15]

# %%
A=3
B=5
C=A+B
print(C)
# Out:
# 8
